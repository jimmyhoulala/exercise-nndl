# %%
import os
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
import torchvision
import torch.nn.functional as F
import numpy as np
learning_rate = 1e-4
keep_prob_rate = 0.7 #
max_epoch = 3
BATCH_SIZE = 50

DOWNLOAD_MNIST = False
if not(os.path.exists('./mnist/')) or not os.listdir('./mnist/'):
    # not mnist dir or mnist is empyt dir
    DOWNLOAD_MNIST = True


train_data = torchvision.datasets.MNIST(root='./mnist/',train=True, transform=torchvision.transforms.ToTensor(), download=DOWNLOAD_MNIST,)
train_loader = Data.DataLoader(dataset = train_data ,batch_size= BATCH_SIZE ,shuffle= True)

test_data = torchvision.datasets.MNIST(root = './mnist/',train = False)
test_x = Variable(torch.unsqueeze(test_data.test_data,dim  = 1),volatile = True).type(torch.FloatTensor)[:500]/255.
test_y = test_data.test_labels[:500].numpy()

class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d( # ???
                # patch 7 * 7 ; 1  in channels ; 32 out channels ; ; stride is 1
                # padding style is same(that means the convolution opration's input and output have the same size)
                in_channels = 1,  
                out_channels = 32,
                kernel_size = 5,
                stride = 1,
                padding = 2,
            ),
            nn.ReLU(),        # activation function
            nn.MaxPool2d(2),  # pooling operation
        )
        self.conv2 = nn.Sequential( # ???
            # line 1 : convolution function, patch 5*5 , 32 in channels ;64 out channels; padding style is same; stride is 1
            # line 2 : choosing your activation funciont
            # line 3 : pooling operation function.
            nn.Conv2d(in_channels=32,out_channels=64,kernel_size=5,stride=1,padding=2),
            nn.ReLU(),
            nn.MaxPool2d(2),
        )
        self.out1 = nn.Linear( 7*7*64 , 1024 , bias= True)   # full connection layer one

        self.dropout = nn.Dropout(keep_prob_rate)
        self.out2 = nn.Linear(1024,10,bias=True)



    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = x.view(x.size(0),-1)  # flatten the output of coonv2 to (batch_size ,32 * 7 * 7)    # ???
        out1 = self.out1(x)
        out1 = F.relu(out1)
        out1 = self.dropout(out1)
        out2 = self.out2(out1)
        output = F.softmax(out2)
        return output


def test(cnn):
    global prediction
    y_pre = cnn(test_x)
    _,pre_index= torch.max(y_pre,1)
    pre_index= pre_index.view(-1)
    prediction = pre_index.data.numpy()
    correct  = np.sum(prediction == test_y)
    return correct / 500.0


def train(cnn):
    optimizer = torch.optim.Adam(cnn.parameters(), lr=learning_rate )
    loss_func = nn.CrossEntropyLoss()
    for epoch in range(max_epoch):
        for step, (x_, y_) in enumerate(train_loader):
            x ,y= Variable(x_),Variable(y_)
            output = cnn(x)  
            loss = loss_func(output,y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            if step != 0 and step % 20 ==0:
                print("=" * 10,step,"="*5,"="*5, "test accuracy is ",test(cnn) ,"=" * 10 )

if __name__ == '__main__':
    cnn = CNN()
    train(cnn)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./mnist/MNIST\raw\train-images-idx3-ubyte.gz
# 100.0%
# Extracting ./mnist/MNIST\raw\train-images-idx3-ubyte.gz to ./mnist/MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./mnist/MNIST\raw\train-labels-idx1-ubyte.gz
# 100.0%
# Extracting ./mnist/MNIST\raw\train-labels-idx1-ubyte.gz to ./mnist/MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./mnist/MNIST\raw\t10k-images-idx3-ubyte.gz
# 100.0%
# Extracting ./mnist/MNIST\raw\t10k-images-idx3-ubyte.gz to ./mnist/MNIST\raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./mnist/MNIST\raw\t10k-labels-idx1-ubyte.gz
# 100.0%
# f:\miniconda3\envs\d2l\lib\site-packages\torchvision\datasets\mnist.py:80: UserWarning: test_data has been renamed data
#   warnings.warn("test_data has been renamed data")
# C:\Users\asus\AppData\Local\Temp\ipykernel_25680\3143077440.py:24: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   test_x = Variable(torch.unsqueeze(test_data.test_data,dim  = 1),volatile = True).type(torch.FloatTensor)[:500]/255.
# f:\miniconda3\envs\d2l\lib\site-packages\torchvision\datasets\mnist.py:70: UserWarning: test_labels has been renamed targets
#   warnings.warn("test_labels has been renamed targets")
# C:\Users\asus\AppData\Local\Temp\ipykernel_25680\3143077440.py:66: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   output = F.softmax(out2)
# Extracting ./mnist/MNIST\raw\t10k-labels-idx1-ubyte.gz to ./mnist/MNIST\raw
#
# ========== 20 ===== ===== test accuracy is  0.222 ==========
# ========== 40 ===== ===== test accuracy is  0.434 ==========
# ========== 60 ===== ===== test accuracy is  0.486 ==========
# ========== 80 ===== ===== test accuracy is  0.616 ==========
# ========== 100 ===== ===== test accuracy is  0.632 ==========
# ========== 120 ===== ===== test accuracy is  0.698 ==========
# ========== 140 ===== ===== test accuracy is  0.76 ==========
# ========== 160 ===== ===== test accuracy is  0.736 ==========
# ========== 180 ===== ===== test accuracy is  0.77 ==========
# ========== 200 ===== ===== test accuracy is  0.814 ==========
# ========== 220 ===== ===== test accuracy is  0.83 ==========
# ========== 240 ===== ===== test accuracy is  0.828 ==========
# ========== 260 ===== ===== test accuracy is  0.844 ==========
# ========== 280 ===== ===== test accuracy is  0.84 ==========
# ========== 300 ===== ===== test accuracy is  0.878 ==========
# ========== 320 ===== ===== test accuracy is  0.862 ==========
# ========== 340 ===== ===== test accuracy is  0.862 ==========
# ========== 360 ===== ===== test accuracy is  0.868 ==========
# ========== 380 ===== ===== test accuracy is  0.894 ==========
# ========== 400 ===== ===== test accuracy is  0.886 ==========
# ========== 420 ===== ===== test accuracy is  0.886 ==========
# ========== 440 ===== ===== test accuracy is  0.892 ==========
# ========== 460 ===== ===== test accuracy is  0.896 ==========
# ========== 480 ===== ===== test accuracy is  0.904 ==========
# ========== 500 ===== ===== test accuracy is  0.914 ==========
# ========== 520 ===== ===== test accuracy is  0.908 ==========
# ========== 540 ===== ===== test accuracy is  0.904 ==========
# ========== 560 ===== ===== test accuracy is  0.906 ==========
# ========== 580 ===== ===== test accuracy is  0.91 ==========
# ========== 600 ===== ===== test accuracy is  0.906 ==========
# ========== 620 ===== ===== test accuracy is  0.916 ==========
# ========== 640 ===== ===== test accuracy is  0.934 ==========
# ========== 660 ===== ===== test accuracy is  0.928 ==========
# ========== 680 ===== ===== test accuracy is  0.93 ==========
# ========== 700 ===== ===== test accuracy is  0.926 ==========
# ========== 720 ===== ===== test accuracy is  0.93 ==========
# ========== 740 ===== ===== test accuracy is  0.92 ==========
# ========== 760 ===== ===== test accuracy is  0.922 ==========
# ========== 780 ===== ===== test accuracy is  0.926 ==========
# ========== 800 ===== ===== test accuracy is  0.924 ==========
# ========== 820 ===== ===== test accuracy is  0.92 ==========
# ========== 840 ===== ===== test accuracy is  0.93 ==========
# ========== 860 ===== ===== test accuracy is  0.932 ==========
# ========== 880 ===== ===== test accuracy is  0.936 ==========
# ========== 900 ===== ===== test accuracy is  0.928 ==========
# ========== 920 ===== ===== test accuracy is  0.932 ==========
# ========== 940 ===== ===== test accuracy is  0.942 ==========
# ========== 960 ===== ===== test accuracy is  0.944 ==========
# ========== 980 ===== ===== test accuracy is  0.942 ==========
# ========== 1000 ===== ===== test accuracy is  0.936 ==========
# ========== 1020 ===== ===== test accuracy is  0.94 ==========
# ========== 1040 ===== ===== test accuracy is  0.956 ==========
# ========== 1060 ===== ===== test accuracy is  0.948 ==========
# ========== 1080 ===== ===== test accuracy is  0.936 ==========
# ========== 1100 ===== ===== test accuracy is  0.952 ==========
# ========== 1120 ===== ===== test accuracy is  0.936 ==========
# ========== 1140 ===== ===== test accuracy is  0.942 ==========
# ========== 1160 ===== ===== test accuracy is  0.954 ==========
# ========== 1180 ===== ===== test accuracy is  0.944 ==========
# ========== 20 ===== ===== test accuracy is  0.956 ==========
# ========== 40 ===== ===== test accuracy is  0.94 ==========
# ========== 60 ===== ===== test accuracy is  0.94 ==========
# ========== 80 ===== ===== test accuracy is  0.956 ==========
# ========== 100 ===== ===== test accuracy is  0.936 ==========
# ========== 120 ===== ===== test accuracy is  0.958 ==========
# ========== 140 ===== ===== test accuracy is  0.956 ==========
# ========== 160 ===== ===== test accuracy is  0.956 ==========
# ========== 180 ===== ===== test accuracy is  0.958 ==========
# ========== 200 ===== ===== test accuracy is  0.954 ==========
# ========== 220 ===== ===== test accuracy is  0.968 ==========
# ========== 240 ===== ===== test accuracy is  0.962 ==========
# ========== 260 ===== ===== test accuracy is  0.948 ==========
# ========== 280 ===== ===== test accuracy is  0.958 ==========
# ========== 300 ===== ===== test accuracy is  0.968 ==========
# ========== 320 ===== ===== test accuracy is  0.97 ==========
# ========== 340 ===== ===== test accuracy is  0.956 ==========
# ========== 360 ===== ===== test accuracy is  0.944 ==========
# ========== 380 ===== ===== test accuracy is  0.958 ==========
# ========== 400 ===== ===== test accuracy is  0.954 ==========
# ========== 420 ===== ===== test accuracy is  0.964 ==========
# ========== 440 ===== ===== test accuracy is  0.964 ==========
# ========== 460 ===== ===== test accuracy is  0.956 ==========
# ========== 480 ===== ===== test accuracy is  0.958 ==========
# ========== 500 ===== ===== test accuracy is  0.948 ==========
# ========== 520 ===== ===== test accuracy is  0.968 ==========
# ========== 540 ===== ===== test accuracy is  0.95 ==========
# ========== 560 ===== ===== test accuracy is  0.958 ==========
# ========== 580 ===== ===== test accuracy is  0.96 ==========
# ========== 600 ===== ===== test accuracy is  0.958 ==========
# ========== 620 ===== ===== test accuracy is  0.954 ==========
# ========== 640 ===== ===== test accuracy is  0.966 ==========
# ========== 660 ===== ===== test accuracy is  0.962 ==========
# ========== 680 ===== ===== test accuracy is  0.954 ==========
# ========== 700 ===== ===== test accuracy is  0.958 ==========
# ========== 720 ===== ===== test accuracy is  0.962 ==========
# ========== 740 ===== ===== test accuracy is  0.96 ==========
# ========== 760 ===== ===== test accuracy is  0.962 ==========
# ========== 780 ===== ===== test accuracy is  0.964 ==========
# ========== 800 ===== ===== test accuracy is  0.958 ==========
# ========== 820 ===== ===== test accuracy is  0.966 ==========
# ========== 840 ===== ===== test accuracy is  0.96 ==========
# ========== 860 ===== ===== test accuracy is  0.964 ==========
# ========== 880 ===== ===== test accuracy is  0.972 ==========
# ========== 900 ===== ===== test accuracy is  0.964 ==========
# ========== 920 ===== ===== test accuracy is  0.966 ==========
# ========== 940 ===== ===== test accuracy is  0.97 ==========
# ========== 960 ===== ===== test accuracy is  0.962 ==========
# ========== 980 ===== ===== test accuracy is  0.97 ==========
# ========== 1000 ===== ===== test accuracy is  0.976 ==========
# ========== 1020 ===== ===== test accuracy is  0.976 ==========
# ========== 1040 ===== ===== test accuracy is  0.966 ==========
# ========== 1060 ===== ===== test accuracy is  0.964 ==========
# ========== 1080 ===== ===== test accuracy is  0.974 ==========
# ========== 1100 ===== ===== test accuracy is  0.96 ==========
# ========== 1120 ===== ===== test accuracy is  0.97 ==========
# ========== 1140 ===== ===== test accuracy is  0.976 ==========
# ========== 1160 ===== ===== test accuracy is  0.964 ==========
# ========== 1180 ===== ===== test accuracy is  0.952 ==========
# ========== 20 ===== ===== test accuracy is  0.976 ==========
# ========== 40 ===== ===== test accuracy is  0.962 ==========
# ========== 60 ===== ===== test accuracy is  0.976 ==========
# ========== 80 ===== ===== test accuracy is  0.976 ==========
# ========== 100 ===== ===== test accuracy is  0.974 ==========
# ========== 120 ===== ===== test accuracy is  0.97 ==========
# ========== 140 ===== ===== test accuracy is  0.97 ==========
# ========== 160 ===== ===== test accuracy is  0.972 ==========
# ========== 180 ===== ===== test accuracy is  0.972 ==========
# ========== 200 ===== ===== test accuracy is  0.97 ==========
# ========== 220 ===== ===== test accuracy is  0.976 ==========
# ========== 240 ===== ===== test accuracy is  0.976 ==========
# ========== 260 ===== ===== test accuracy is  0.962 ==========
# ========== 280 ===== ===== test accuracy is  0.956 ==========
# ========== 300 ===== ===== test accuracy is  0.958 ==========
# ========== 320 ===== ===== test accuracy is  0.966 ==========
# ========== 340 ===== ===== test accuracy is  0.972 ==========
# ========== 360 ===== ===== test accuracy is  0.974 ==========
# ========== 380 ===== ===== test accuracy is  0.976 ==========
# ========== 400 ===== ===== test accuracy is  0.98 ==========
# ========== 420 ===== ===== test accuracy is  0.976 ==========
# ========== 440 ===== ===== test accuracy is  0.962 ==========
# ========== 460 ===== ===== test accuracy is  0.972 ==========
# ========== 480 ===== ===== test accuracy is  0.976 ==========
# ========== 500 ===== ===== test accuracy is  0.972 ==========
# ========== 520 ===== ===== test accuracy is  0.98 ==========
# ========== 540 ===== ===== test accuracy is  0.966 ==========
# ========== 560 ===== ===== test accuracy is  0.978 ==========
# ========== 580 ===== ===== test accuracy is  0.972 ==========
# ========== 600 ===== ===== test accuracy is  0.97 ==========
# ========== 620 ===== ===== test accuracy is  0.98 ==========
# ========== 640 ===== ===== test accuracy is  0.978 ==========
# ========== 660 ===== ===== test accuracy is  0.972 ==========
# ========== 680 ===== ===== test accuracy is  0.974 ==========
# ========== 700 ===== ===== test accuracy is  0.974 ==========
# ========== 720 ===== ===== test accuracy is  0.97 ==========
# ========== 740 ===== ===== test accuracy is  0.978 ==========
# ========== 760 ===== ===== test accuracy is  0.974 ==========
# ========== 780 ===== ===== test accuracy is  0.978 ==========
# ========== 800 ===== ===== test accuracy is  0.978 ==========
# ========== 820 ===== ===== test accuracy is  0.982 ==========
# ========== 840 ===== ===== test accuracy is  0.966 ==========
# ========== 860 ===== ===== test accuracy is  0.972 ==========
# ========== 880 ===== ===== test accuracy is  0.974 ==========
# ========== 900 ===== ===== test accuracy is  0.982 ==========
# ========== 920 ===== ===== test accuracy is  0.964 ==========
# ========== 940 ===== ===== test accuracy is  0.984 ==========
# ========== 960 ===== ===== test accuracy is  0.968 ==========
# ========== 980 ===== ===== test accuracy is  0.988 ==========
# ========== 1000 ===== ===== test accuracy is  0.974 ==========
# ========== 1020 ===== ===== test accuracy is  0.972 ==========
# ========== 1040 ===== ===== test accuracy is  0.98 ==========
# ========== 1060 ===== ===== test accuracy is  0.964 ==========
# ========== 1080 ===== ===== test accuracy is  0.982 ==========
# ========== 1100 ===== ===== test accuracy is  0.98 ==========
# ========== 1120 ===== ===== test accuracy is  0.968 ==========
# ========== 1140 ===== ===== test accuracy is  0.97 ==========
# ========== 1160 ===== ===== test accuracy is  0.984 ==========
# ========== 1180 ===== ===== test accuracy is  0.972 ==========
